# %% [markdown]
# # UAV MPC Planner - Robustness Evaluation
#
# This notebook provides the analysis of the Monte Carlo trials simulating random wind and turbulence using the CasADi optimized MPC controller.

# %% [markdown]
# ## 1. Simulation Context
# The 6-DOF Quadrotor is subjected to stochastic Dryden-style wind disturbance models across varying magnitudes (up to 8m/s mean) and turbulence intensities.
# The Non-Linear MPC operates at 50Hz, solving a 20-step horizon.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Validation bounds based on project specifications
target_mean_error = 0.08  # meters
target_stability = 97.5   # %

print(f"Validation threshold for Mean Position Error: {target_mean_error} m")
print(f"Validation threshold for Flight Stability: {target_stability} %")

# %% [markdown]
# ## 2. Quantitative Results
# *Note: Execute `python3 evaluation/monte_carlo/run_monte_carlo.py` to generate the raw distributions.*
